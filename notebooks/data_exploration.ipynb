# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

import seaborn as sns

# %load_ext autoreload
# %autoreload 2

# %%
# load the dataset
yield_df = pd.read_csv(r'..\data\raw\yield_df.csv', index_col=0)

# %%
# check for missing values
missing_values = yield_df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  Area                             0
# Item                             0
# Year                             0
# hg/ha_yield                      0
# average_rain_fall_mm_per_year    0
# pesticides_tonnes                0
# avg_temp                         0
# dtype: int64

# %%
yield_df.columns
# Out:
# Index(['Area', 'Item', 'Year', 'hg/ha_yield', 'average_rain_fall_mm_per_year',
#        'pesticides_tonnes', 'avg_temp'],
#       dtype='object')

# %%
sns.pairplot(yield_df)

# %%
sns.histplot(yield_df['hg/ha_yield'], bins=50, kde=True)
# Out:
# <Axes: xlabel='hg/ha_yield', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(16,6))

plt.scatter(yield_df['Item'], yield_df['hg/ha_yield'])

# %%
fig, ax = plt.subplots(figsize=(20,6))

plt.scatter(yield_df['Area'], yield_df['hg/ha_yield'])
plt.xticks(rotation=90)
plt.xlabel('Area')
# Out:
# Text(0.5, 0, 'Area')

# %%
fig, ax = plt.subplots(figsize=(16,6))

sns.scatterplot(data=yield_df, x='Area', y='hg/ha_yield', ax=ax, hue='Item')
plt.xticks(rotation=90)
plt.xlabel('Area')
# Out:
# Text(0.5, 0, 'Area')
