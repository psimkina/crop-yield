# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\GPGWX\OneDrive - Bayer\psimkina\SAMPLE_PROJECTS\crop-yield\data\raw\yield_df.csv")

# %%
df.head(6)
# Out:
#    Unnamed: 0     Area         Item  Year  hg/ha_yield  \
# 0           0  Albania        Maize  1990        36613
# 1           1  Albania     Potatoes  1990        66667
# 2           2  Albania  Rice, paddy  1990        23333
# 3           3  Albania      Sorghum  1990        12500
# 4           4  Albania     Soybeans  1990         7000
# 5           5  Albania        Wheat  1990        30197
#
#    average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                         1485.0              121.0     16.37
# 1                         1485.0              121.0     16.37
# 2                         1485.0              121.0     16.37
# 3                         1485.0              121.0     16.37
# 4                         1485.0              121.0     16.37
# 5                         1485.0              121.0     16.37

# %%
from src.data import load_data, clean_dataframe, split_data

# %%
path = r"C:\Users\GPGWX\OneDrive - Bayer\psimkina\SAMPLE_PROJECTS\crop-yield\data\raw\yield_df.csv"

data = load_data(path)
data = clean_dataframe(data)

# %%
X_train, X_test, y_train, y_test = split_data(data, target_column='hg/ha_yield')

# %%
X_train
# Out:
#                      area            item  year  \
# 24234        Saudi Arabia         Sorghum  2000
# 9468               Greece  Sweet potatoes  2012
# 6793             Colombia           Maize  2006
# 28212            Zimbabwe        Potatoes  2010
# 7358   Dominican Republic  Sweet potatoes  2007
# ...                   ...             ...   ...
# 23678            Portugal  Sweet potatoes  2004
# 5960               Canada           Wheat  2006
# 860             Australia        Potatoes  1991
# 17223          Kazakhstan        Potatoes  1998
# 25918            Suriname         Cassava  1994
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 24234                           59.0            3024.11     26.55
# 9468                           652.0            8002.20     18.82
# 6793                          3240.0           98328.63     27.51
# 28212                          657.0            3305.17     21.17
# ...
